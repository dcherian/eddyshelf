# %% [markdown]
# # Maps of useful dimensional and non-dimensional parameters for the coastal world ocean

# %%
# %matplotlib inline
# %load_ext secnum
# %secnum

import numpy as np
import scipy as sp
import h5py
import netCDF4 

import sys
sys.path.append('/media/data/Work/tools/python/dc/')
from dcutils import *

import numexpr as ne
from scipy.io import loadmat
import scipy.interpolate

from scipy import ndimage
from skimage import filter

from datetime import datetime
import time
from IPython import display
import pylab

import seawater as sw

# matplotlib section
import matplotlib as mpl
import matplotlib.pyplot as plt
# big figures
mpl.rcParams['savefig.dpi'] = 2 * mpl.rcParams['savefig.dpi']
# better color cycling
import brewer2mpl
colors =  brewer2mpl.get_map('Set2', 'qualitative', 8).mpl_colors
mpl.rcParams['axes.color_cycle'] = colors

# %% [markdown]
# Read in data files - etopo for bathymetry, WOA to calculate stratification

# %%
# load ETOPO2 bathymetry - convert to ETOPO1 eventually
bathyfile = 'data/etopo2_extract.mat'
bathy = loadmat(bathyfile, struct_as_record=False, squeeze_me=True)
topo = bathy['topo'] # pull out the topo structure


# land mask>
landmask = topo.z > 0

# %%
# dx,dy need to be converted from dlon,dlat to metres
dx = np.diff(topo.x).mean()*110000;
dy = np.diff(topo.y).mean()*110000;

# calculate gradients assuming dx=dy=1
hy, hx = np.gradient(topo.z)
hxy, hxx = np.gradient(hx)
hyy, _ = np.gradient(hy)

# get actual gradient
hx /= dx
hy /= dy
hxy /= (dx * dy)
hxx /= (dx * dx)
hyy /= (dy * dy)

# apply land mask
slope = np.ma.masked_array(np.sqrt(hx**2 + hy**2), 
                           landmask)

# get Gaussian curvature
curv = np.abs(np.ma.masked_array((hxx * hyy - (hxy **2)) / 
                          (1 + (hx **2) + (hy**2)) ** 2, 
                          landmask))

# %%
# plot
fig = plt.figure()
ax = fig.gca()
handle = ax.pcolorfast(topo.x[::3], topo.y[::3], slope[::3,::3].T, cmap='OrRd')
fig.colorbar(handle)
fig.hold(True)
ax.contour(topo.x[::5], topo.y[::5], topo.z[::5,::5].T, levels=[0], colors='k')
ax.set_title('Magn. of bathymetric slope')

fig = plt.figure()
ax = fig.gca()
handle = ax.pcolorfast(topo.x, topo.y, 
                       np.ma.masked_array(filter.prewitt(topo.z).T, landmask.T), 
                       cmap='OrRd')
fig.colorbar(handle)
fig.hold(True)
ax.contour(topo.x[::5], topo.y[::5], topo.z[::5,::5].T, levels=[0], colors='k')
ax.set_title('Magn. of bathymetric slope')

# %% [markdown]
# Thresholding this image (limiting the max) returns a pretty sharp edge. I think I can use this and some existing edge detection algorithm.

# %%
f = plt.figure()
ax = f.gca();
handle = ax.pcolorfast(topo.x[::3], topo.y[::3], curv[::3,::3].T, cmap='OrRd')
f.colorbar(handle)
handle.set_clim((0,1e-11))
plt.title('Gaussian topography curvature')

# %% [markdown]
# Gaussian curvature looks noisy and there's a question of extracting the contour from it.

# %%
thresh = filter.threshold_otsu(
print(thresh)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-b6031168837f> in <module>()
# ----> 1 thresh = filter.threshold_otsu(np.ma.asanyarray(slope))
#       2 print(thresh)
#
# /usr/local/lib/python2.7/dist-packages/skimage/filter/thresholding.pyc in threshold_otsu(image, nbins)
#     117     >>> binary = image <= thresh
#     118     """
# --> 119     hist, bin_centers = histogram(image, nbins)
#     120     hist = hist.astype(float)
#     121
#
# /usr/local/lib/python2.7/dist-packages/skimage/exposure/exposure.pyc in histogram(image, nbins)
#      65         return hist[idx:], bin_centers[idx:]
#      66     else:
# ---> 67         hist, bin_edges = np.histogram(image.flat, nbins)
#      68         bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2.
#      69         return hist, bin_centers
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     174             else:
#     175                 range = (a.min(), a.max())
# --> 176         mn, mx = [mi+0.0 for mi in range]
#     177         if mn == mx:
#     178             mn -= 0.5
#
# TypeError: unsupported operand type(s) for +: 'MaskedIterator' and 'float'

# %%
# based on http://scikit-image.org/docs/dev/auto_examples/plot_canny.html


# create image
im = (slope > 0.004)

deepmask = topo.z < -4000

edges = (filter.sobel(topo.z, mask=(~landmask *~deepmask)) > 1e-2)

import skimage.morphology as morph
edges = morph.skeletonize(edges)

f = plt.figure()
a = f.gca()
plt.imshow(im.T)
plt.colorbar()
a.invert_yaxis()

fig = plt.figure()
ax = fig.gca()
hsb = ax.pcolorfast(topo.x, topo.y, edges.T * topo.z.T, cmap='Greys_r')
ax.hold(True)
ax.contour(topo.x[::5], topo.y[::5], topo.z[::5,::5].T, levels=[0], colors='k')
fig.colorbar(hsb)
#ax.set_xlim((-75, -60))
#ax.set_ylim((35, 45))
##hsb.set_clim((0,250))
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11ba5d6c8>
